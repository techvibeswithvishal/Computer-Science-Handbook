# %% [markdown]
# # 📘 Chapter 7: WHERE Clause
#
# ---
#
# # 🎯 Learning Objectives
#
# After completing this chapter, you will be able to:
#
# - Filter records from a table
# - Use comparison operators
# - Use logical operators
# - Retrieve records based on conditions
# - Write real-world SQL filtering queries
#
# ---
#
# # 📖 What is the WHERE Clause?
#
# The **WHERE** clause is used to filter records based on one or more conditions.
#
# Instead of displaying all rows, it returns only the rows that satisfy the given condition.
#
# ---
#
# # Basic Syntax
#
# ```sql
# SELECT column_name
# FROM table_name
# WHERE condition;
# ```
#
# ---
#
# # Example Table
#
# Students
#
# | id | name | age | city |
# |----|------|-----|-------|
# |1|Vishal|23|Delhi|
# |2|Rahul|22|Agra|
# |3|Neha|21|Delhi|
# |4|Aman|24|Noida|
#
# ---
#
# # 1. Equal To (=)
#
# Display students from Delhi.
#
# ```sql
# SELECT *
# FROM students
# WHERE city = 'Delhi';
# ```
#
# Output
#
# | id | name | age | city |
# |----|------|-----|-------|
# |1|Vishal|23|Delhi|
# |3|Neha|21|Delhi|
#
# ---
#
# # 2. Greater Than (>)
#
# Display students older than 22.
#
# ```sql
# SELECT *
# FROM students
# WHERE age > 22;
# ```
#
# ---
#
# # 3. Less Than (<)
#
# ```sql
# SELECT *
# FROM students
# WHERE age < 23;
# ```
#
# ---
#
# # 4. Greater Than or Equal To (>=)
#
# ```sql
# SELECT *
# FROM students
# WHERE age >= 23;
# ```
#
# ---
#
# # 5. Less Than or Equal To (<=)
#
# ```sql
# SELECT *
# FROM students
# WHERE age <= 22;
# ```
#
# ---
#
# # 6. Not Equal To (!=)
#
# ```sql
# SELECT *
# FROM students
# WHERE city != 'Delhi';
# ```
#
# or
#
# ```sql
# SELECT *
# FROM students
# WHERE city <> 'Delhi';
# ```
#
# ---
#
# # Comparison Operators
#
# | Operator | Meaning |
# |----------|---------|
# | = | Equal To |
# | > | Greater Than |
# | < | Less Than |
# | >= | Greater Than or Equal To |
# | <= | Less Than or Equal To |
# | != or <> | Not Equal To |
#
# ---
#
# # Logical Operators
#
# ## AND
#
# Both conditions must be true.
#
# ```sql
# SELECT *
# FROM students
# WHERE city='Delhi'
# AND age > 22;
# ```
#
# ---
#
# ## OR
#
# At least one condition must be true.
#
# ```sql
# SELECT *
# FROM students
# WHERE city='Delhi'
# OR city='Agra';
# ```
#
# ---
#
# ## NOT
#
# Returns opposite results.
#
# ```sql
# SELECT *
# FROM students
# WHERE NOT city='Delhi';
# ```
#
# ---
#
# # Complete Example
#
# ```sql
# SELECT *
# FROM students
# WHERE age > 20;
#
# SELECT *
# FROM students
# WHERE city='Delhi';
#
# SELECT *
# FROM students
# WHERE age>=22
# AND city='Delhi';
#
# SELECT *
# FROM students
# WHERE city='Agra'
# OR city='Noida';
#
# SELECT *
# FROM students
# WHERE city!='Delhi';
# ```
#
# ---
#
# # Interview Questions
#
# ### 1. What is the WHERE clause?
#
# It filters records based on a condition.
#
# ---
#
# ### 2. Which operator checks equality?
#
# ```sql
# =
# ```
#
# ---
#
# ### 3. Difference between AND and OR?
#
# | AND | OR |
# |-----|----|
# | All conditions must be true | At least one condition must be true |
#
# ---
#
# ### 4. Which operator checks "Not Equal"?
#
# ```sql
# !=
#
# or
#
# <>
# ```
#
# ---
#
# ### 5. Can WHERE be used without SELECT?
#
# No.
#
# WHERE is generally used with SELECT, UPDATE, or DELETE.
#
# ---
#
# # Common Mistakes
#
# ❌ Forgetting quotes for text values
#
# Wrong
#
# ```sql
# WHERE city = Delhi;
# ```
#
# Correct
#
# ```sql
# WHERE city = 'Delhi';
# ```
#
# ---
#
# ❌ Using = instead of ==
#
# SQL uses
#
# ```sql
# =
# ```
#
# NOT
#
# ```sql
# ==
# ```
#
# ---
#
# # Practice Questions
#
# ### Question 1
#
# Display students whose age is greater than 21.
#
# ---
#
# ### Question 2
#
# Display students from Delhi.
#
# ---
#
# ### Question 3
#
# Display students whose age is greater than 22 and city is Delhi.
#
# ---
#
# ### Question 4
#
# Display students whose city is Agra or Noida.
#
# ---
#
# ### Question 5
#
# Display students who are not from Delhi.
#
# ---
#
# # Chapter Summary
#
# ```text
# ✓ WHERE
#
# ✓ Comparison Operators
#
# ✓ =
#
# ✓ >
#
# ✓ <
#
# ✓ >=
#
# ✓ <=
#
# ✓ !=
#
# ✓ <>
#
# ✓ AND
#
# ✓ OR
#
# ✓ NOT
# ```
