# %% [markdown]
# # 📘 Chapter 15: SQL Practice Questions
#
# ---
#
# # 🎯 Learning Objectives
#
# After completing this chapter, you will be able to:
#
# - Apply all SQL concepts learned so far
# - Practice writing SQL queries
# - Improve problem-solving skills
# - Prepare for LeetCode SQL 50
# - Prepare for Software Engineering interviews
#
# ---
#
# # 📚 Database Setup
#
# Use the following table for all practice questions.
#
# ```sql
# CREATE TABLE students(
#     id INT PRIMARY KEY,
#     name VARCHAR(50),
#     age INT,
#     city VARCHAR(30),
#     marks INT
# );
#
# INSERT INTO students VALUES
# (1,'Vishal',23,'Delhi',90),
# (2,'Rahul',22,'Agra',75),
# (3,'Neha',21,'Delhi',85),
# (4,'Aman',24,'Noida',60),
# (5,'Priya',20,'Agra',95),
# (6,'Riya',23,'Delhi',80);
# ```
#
# ---
#
# # 🟢 Basic Level
#
# ### Question 1
#
# Display all students.
#
# ---
#
# ### Question 2
#
# Display only
#
# - name
# - city
#
# ---
#
# ### Question 3
#
# Display students whose city is Delhi.
#
# ---
#
# ### Question 4
#
# Display students whose age is greater than 21.
#
# ---
#
# ### Question 5
#
# Display students whose marks are greater than 80.
#
# ---
#
# ### Question 6
#
# Display students from Agra.
#
# ---
#
# ### Question 7
#
# Display students whose age is between 20 and 23.
#
# ---
#
# ### Question 8
#
# Display students whose city is Delhi or Agra.
#
# ---
#
# ### Question 9
#
# Display students whose city is not Delhi.
#
# ---
#
# ### Question 10
#
# Display students whose name starts with 'V'.
#
# ---
#
# # 🟡 Intermediate Level
#
# ### Question 11
#
# Display students sorted by marks (Highest to Lowest).
#
# ---
#
# ### Question 12
#
# Display students sorted alphabetically by name.
#
# ---
#
# ### Question 13
#
# Display only unique cities.
#
# ---
#
# ### Question 14
#
# Count the total number of students.
#
# ---
#
# ### Question 15
#
# Find the average marks.
#
# ---
#
# ### Question 16
#
# Find the highest marks.
#
# ---
#
# ### Question 17
#
# Find the lowest marks.
#
# ---
#
# ### Question 18
#
# Find the total marks of all students.
#
# ---
#
# ### Question 19
#
# Count students city-wise.
#
# ---
#
# ### Question 20
#
# Find the average marks city-wise.
#
# ---
#
# # 🟠 Advanced Level
#
# ### Question 21
#
# Display cities having more than one student.
#
# ---
#
# ### Question 22
#
# Display students whose marks are above the average marks.
#
# ---
#
# ### Question 23
#
# Display the student(s) having the highest marks.
#
# ---
#
# ### Question 24
#
# Display the student(s) having the lowest marks.
#
# ---
#
# ### Question 25
#
# Display the second highest marks.
#
# ---
#
# ### Question 26
#
# Create a view named TopStudents containing students with marks greater than 80.
#
# ---
#
# ### Question 27
#
# Display data from TopStudents.
#
# ---
#
# ### Question 28
#
# Delete the TopStudents view.
#
# ---
#
# ### Question 29
#
# Create another table named Courses.
#
# ```text
# course_id
# student_id
# course_name
# ```
#
# Perform an INNER JOIN with Students.
#
# ---
#
# ### Question 30
#
# Display all students even if they are not enrolled in any course.
#
# (Hint: LEFT JOIN)
#
# ---
#
# # 🎯 Challenge Questions
#
# ### Challenge 1
#
# Find all students whose names contain the letter 'a'.
#
# ---
#
# ### Challenge 2
#
# Display students from Delhi whose marks are greater than 80.
#
# ---
#
# ### Challenge 3
#
# Display students whose marks are between 70 and 90.
#
# ---
#
# ### Challenge 4
#
# Display the top 3 students based on marks.
#
# ---
#
# ### Challenge 5
#
# Display city-wise maximum marks.
#
# ---
#
# ### Challenge 6
#
# Display city-wise minimum marks.
#
# ---
#
# ### Challenge 7
#
# Display city-wise total marks.
#
# ---
#
# ### Challenge 8
#
# Display city-wise average marks.
#
# ---
#
# ### Challenge 9
#
# Display students whose marks are equal to the highest marks.
#
# ---
#
# ### Challenge 10
#
# Display students whose age is equal to the minimum age.
#
# ---
#
# # 🚀 SQL Challenge
#
# Try solving these questions **without looking at your notes**.
#
# If you get stuck:
#
# 1. Read the question carefully.
# 2. Identify the SQL clause needed.
# 3. Write the query.
# 4. Execute it.
# 5. Verify the output.
#
# ---
#
# # 📈 Difficulty Progress
#
# ```text
# Basic        ⭐☆☆☆☆
#
# Intermediate ⭐⭐⭐☆☆
#
# Advanced     ⭐⭐⭐⭐☆
#
# Challenge    ⭐⭐⭐⭐⭐
# ```
#
# ---
#
# # 🎯 Next Step
#
# After completing these practice questions:
#
# ✅ Start LeetCode SQL 50
#
# Target:
#
# - Solve 2 SQL problems daily.
# - Understand the logic before checking solutions.
# - Maintain your solutions in your GitHub repository.
#
# ---
#
# # Chapter Summary
#
# ```text
# ✓ 30 SQL Practice Questions
#
# ✓ Beginner Level
#
# ✓ Intermediate Level
#
# ✓ Advanced Level
#
# ✓ Challenge Questions
#
# ✓ Interview Preparation
#
# ✓ LeetCode Preparation
# ```
