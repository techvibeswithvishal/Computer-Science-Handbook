# %% [markdown]
# # User Input
#
# * `input()` is used to take input from the user.
# * By default, `input()` returns data as a **string (str)**.
#
# ### Example
#
# ```python
# name = input("Enter your name: ")
# print(name)
# ```
#
# # Type Conversion
#
# Type conversion means converting one data type into another.
#
# ### Types of Conversion
#
# ### 1. Implicit Conversion
#
# * Performed automatically by Python.
#
# ```python
# print(5 + 5.6)
# ```
#
# Output:
#
# ```python
# 10.6
# ```
#
# ### 2. Explicit Conversion
#
# * Performed manually using conversion functions.
#
# ```python
# int("4")
# float(4)
# str(5)
# bool(1)
# complex(4)
# ```
#
# ### Example
#
# ```python
# first_num = int(input("Enter first number: "))
# second_num = int(input("Enter second number: "))
#
# result = first_num + second_num
#
# print(result)
# ```
#
# ### Common Conversion Functions
#
# ```python
# int()
# float()
# str()
# bool()
# complex()
# list()
# tuple()
# set()
# ```

# %%
name = input("Enter your name please: ")
email = input("Enter your email please: ")
entry2 = input("Enter your age: ")
b=5
c=7
d=9
e= b+c+d
print(name)
print(email)
print(entry2)
print(name, email, entry2)
print(e)
# Out:
# Enter your name please:  vishal
# Enter your email please:  v@gmail.com
# Enter your age:  22
# vishal
# v@gmail.com
# 22
# vishal v@gmail.com 22
# 21

# %%
print("========== STUDENT REGISTRATION FORM ==========")

name = input("Enter Your Name: ")
email = input("Enter Your Email: ")
age = int(input("Enter Your Age: "))
phone = input("Enter Your Phone Number: ")
city = input("Enter Your City: ")
college = input("Enter Your College Name: ")
branch = input("Enter Your Branch: ")
semester = int(input("Enter Your Semester: "))
cgpa = float(input("Enter Your CGPA: "))

print("\n========== STUDENT DETAILS ==========")

print("Name      :", name)
print("Email     :", email)
print("Age       :", age)
print("Phone     :", phone)
print("City      :", city)
print("College   :", college)
print("Branch    :", branch)
print("Semester  :", semester)
print("CGPA      :", cgpa)

print("\nRegistration Successful!")
# Out:
# ========== STUDENT REGISTRATION FORM ==========
# Enter Your Name:  vishal singh
# Enter Your Email:  v@gmail.com
# Enter Your Age:  22
# Enter Your Phone Number:  9999999999
# Enter Your City:  Delhi
# Enter Your College Name:  vctm
# Enter Your Branch:  cse
# Enter Your Semester:  8
# Enter Your CGPA:  9
# ========== STUDENT DETAILS ==========
# Name      : vishal singh
# Email     : v@gmail.com
# Age       : 22
# Phone     : 9999999999
# City      : Delhi
# College   : vctm
# Branch    : cse
# Semester  : 8
# CGPA      : 9.0
#
# Registration Successful!
