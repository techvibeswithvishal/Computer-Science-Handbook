# %%
print("SING UP")
name = input("Enter your name: ")
email = input("Enter your email: ")
password= int(input("Enter your password: "))
if "@" in email:
    print(email , "valid")
    print()
    print()
    print("login ")
    l= int(input("Enter again password: "))
    if password == l:
        a=input("please enter your phone number : ")
        b=input("your username : ")
        print("please check your entries => " )
        print(name)
        print(email)
        print(a)
        print(b)
    else :
        print("out of syllabus")
else:
    print("Invalid Email")
# Out:
# SING UP
# Enter your name:  hello
# Enter your email:  hello@gmail.com
# Enter your password:  1234
# hello@gmail.com valid
#
#
# login
# Enter again password:  1234
# please enter your phone number :  999999999
# your username :  vishal
# please check your entries =>
# hello
# hello@gmail.com
# 999999999
# vishal
