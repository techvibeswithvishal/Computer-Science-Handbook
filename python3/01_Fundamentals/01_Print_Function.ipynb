# %%
print("vishal")
# Out:
# vishal

# %%
print("vishal","singh", "developer", "dream")
# Out:
# vishal singh developer dream

# %%
print("vishal", "singh", sep=" ❤️")
# Out:
# vishal ❤️singh

# %%
print("vishal")
print("singh")
print("vishal", end=" ")
print("singh")
print("vishal", end="-")
print("singh")
# Out:
# vishal
# singh
# vishal singh
# vishal-singh
