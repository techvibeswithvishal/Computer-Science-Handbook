# %% [markdown]
# Variables in Python
#
# A variable is a container that is used to store a value.

# %%
a=4
b=5
c=7
d="vishal"
print(a+b+c)
print(a,b,c)
print(a*b*c)
print(type(a))
print(type(d))
# Out:
# 16
# 4 5 7
# 140
# <class 'int'>
# <class 'str'>

# %%
a,b,c=4,5,7
print(a+b+c)
print(a,b,c)
print(a*b*c)
print(type(a))
print(type(d))
# Out:
# 16
# 4 5 7
# 140
# <class 'int'>
# <class 'str'>
