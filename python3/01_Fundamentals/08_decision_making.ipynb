# %% [markdown]
# **If-else**

# %%
x = int(input("Enter a number: "))

if x > 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Enter a number:  3
# Positive

# %% [markdown]
# **if-elif**

# %%
num = int(input("enter : " ))

if num == 1:
    print("Condition 1")
elif num == 2:
    print("Condition 2")
elif num == 3:
    print("Condition 3")
elif num == 4:
    print("Condition 4")
elif num == 5:
    print("Condition 5")
elif num == 6:
    print("Condition 6")
elif num == 7:
    print("Condition 7")
elif num == 8:
    print("Condition 8")
else:
    print("Invalid Condition")
# Out:
# enter :  110
# Invalid Condition
