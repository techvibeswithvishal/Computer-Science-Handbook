# %% [markdown]
# # 📘 05_For_Loop
#
# ## Learning Objectives
#
# - Learn iteration using `for`.
#
# ---
#
# ## What is For Loop?
#
# Repeats a block for every item in a sequence.
#
# ---
#
# ## Syntax
#
# ```python
# for variable in sequence:
#     statements
# ```
#
# ---
#
# ## Example
#
# ```python
# for i in range(1,6):
#     print(i)
# ```
#
# ---
#
# ## Practice Questions
#
# 1. Print 1–100.
# 2. Sum of numbers.
# 3. Multiplication table.
# 4. Factorial.
# 5. Fibonacci.
#
# ---
#
# ## Interview Questions
#
# - Difference between `for` and `while`.
# - Uses of `range()`.
#
# ---
#
# ## Summary
#
# - Best for known iterations.

# %%
x = int(input("enter number : "))
n=11
for i in range (1,11):
    i= x*i
    print(i)
# Out:
# enter number :  6
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60

# %%
num = int(input("Enter a number: "))

for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
# Enter a number:  6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
