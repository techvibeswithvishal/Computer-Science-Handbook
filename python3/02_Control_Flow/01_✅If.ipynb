# %% [markdown]
# # 📘 If Statement
#
# ## Learning Objectives
#
# - Understand the `if` statement.
# - Learn how decision making works in Python.
# - Write programs using conditional execution.
#
# ---
#
# ## What is an If Statement?
#
# The `if` statement executes a block of code only when the given condition evaluates to `True`.
#
# ---
#
# ## Syntax
#
# ```python
# if condition:
#     statement

# %%
a = input("enter digit please : ")

if a==0:
 print("yahoo please chill")
else :
  print("life is not fun")
# Out:
# enter digit please :  9
# life is not fun
